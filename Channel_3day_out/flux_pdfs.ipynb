# %%
# load modules 

import xarray as xr
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import numpy as np
from xgcm import Grid

# %%
dir_zarr = '/swot/SUM04/dbalwada/channel_model/05km_sponge/run_tracers_restored_3day_output/run_tracers_restored_zarr/'
ds_model = xr.open_zarr(dir_zarr)

# %%
ds_model
# Out:
# <xarray.Dataset>
# Dimensions:              (XC: 400, XG: 400, YC: 400, YG: 400, Z: 40, Zl: 40, Zp1: 41, Zu: 40, layer_1TH_bounds: 43, layer_1TH_center: 42, layer_1TH_interface: 41, time: 1980)
# Coordinates:
#     Depth                (YC, XC) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#     PHrefC               (Z) float32 dask.array<shape=(40,), chunksize=(1,)>
#     PHrefF               (Zp1) float32 dask.array<shape=(41,), chunksize=(41,)>
#   * XC                   (XC) float32 2500.0 7500.0 ... 1992500.0 1997500.0
#   * XG                   (XG) float32 0.0 5000.0 10000.0 ... 1990000.0 1995000.0
#   * YC                   (YC) float32 2500.0 7500.0 ... 1992500.0 1997500.0
#   * YG                   (YG) float32 0.0 5000.0 10000.0 ... 1990000.0 1995000.0
#   * Z                    (Z) float32 -5.0 -15.0 -25.0 ... -2830.5 -2933.5
#   * Zl                   (Zl) float32 0.0 -10.0 -20.0 ... -2779.0 -2882.0
#   * Zp1                  (Zp1) float32 0.0 -10.0 -20.0 ... -2882.0 -2985.0
#   * Zu                   (Zu) float32 -10.0 -20.0 -30.0 ... -2882.0 -2985.0
#     drC                  (Zp1) float32 dask.array<shape=(41,), chunksize=(41,)>
#     drF                  (Z) float32 dask.array<shape=(40,), chunksize=(1,)>
#     dxC                  (YC, XG) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#     dxG                  (YG, XC) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#     dyC                  (YG, XC) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#     dyG                  (YC, XG) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#     hFacC                (Z, YC, XC) float32 dask.array<shape=(40, 400, 400), chunksize=(1, 400, 400)>
#     hFacS                (Z, YG, XC) float32 dask.array<shape=(40, 400, 400), chunksize=(1, 400, 400)>
#     hFacW                (Z, YC, XG) float32 dask.array<shape=(40, 400, 400), chunksize=(1, 400, 400)>
#     iter                 (time) int64 dask.array<shape=(1980,), chunksize=(35,)>
#   * layer_1TH_bounds     (layer_1TH_bounds) float32 -0.2 0.0 0.2 ... 7.8 8.0 8.2
#   * layer_1TH_center     (layer_1TH_center) float32 -0.1 0.1 0.3 ... 7.7 7.9 8.1
#   * layer_1TH_interface  (layer_1TH_interface) float32 0.0 0.2 0.4 ... 7.8 8.0
#     maskC                (Z, YC, XC) bool dask.array<shape=(40, 400, 400), chunksize=(1, 400, 400)>
#     maskS                (Z, YG, XC) bool dask.array<shape=(40, 400, 400), chunksize=(1, 400, 400)>
#     maskW                (Z, YC, XG) bool dask.array<shape=(40, 400, 400), chunksize=(1, 400, 400)>
#     rA                   (YC, XC) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#     rAs                  (YG, XC) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#     rAw                  (YC, XG) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#     rAz                  (YG, XG) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#   * time                 (time) timedelta64[ns] 61023 days ... 66960 days
# Data variables:
#     Eta                  (time, YC, XC) float32 dask.array<shape=(1980, 400, 400), chunksize=(35, 400, 400)>
#     PH                   (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PHL                  (time, YC, XC) float32 dask.array<shape=(1980, 400, 400), chunksize=(35, 400, 400)>
#     PTRACER01            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER02            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER03            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER04            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER05            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER06            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER07            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER08            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER09            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER10            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER11            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER12            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER13            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER14            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER15            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER16            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER17            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER18            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER19            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER20            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     T                    (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     U                    (time, Z, YC, XG) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     V                    (time, Z, YG, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     W                    (time, Zl, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>

# %%
ds_model.U.sel(Z=-1000, XG=0, YC=1000e3, method='nearest').plot()

# %%
ds_model.V.sel(Z=-1000, XC=0, YG=1000e3, method='nearest').plot()

# %%
bins = np.linspace(-0.4, 0.4,27)
ds_model.V.sel(Z=-1000, XC=0, YG=1000e3, method='nearest').plot.hist(bins=bins)
# Out:
# (array([  2.,   0.,   7.,  11.,  24.,  45.,  64.,  99., 116., 168., 165.,
#         164., 183., 182., 140., 143., 136., 108.,  80.,  62.,  35.,  20.,
#          15.,   8.,   1.,   1.]),
#  array([-0.4       , -0.36923077, -0.33846154, -0.30769231, -0.27692308,
#         -0.24615385, -0.21538462, -0.18461538, -0.15384615, -0.12307692,
#         -0.09230769, -0.06153846, -0.03076923,  0.        ,  0.03076923,
#          0.06153846,  0.09230769,  0.12307692,  0.15384615,  0.18461538,
#          0.21538462,  0.24615385,  0.27692308,  0.30769231,  0.33846154,
#          0.36923077,  0.4       ]),
#  <a list of 26 Patch objects>)

# %%
ds_model.V.sel(Z=-1000, XC=0, YG=1000e3, method='nearest').mean('time').values
# Out:
# array(-0.00666834, dtype=float32)

# %%
ds_model.V.sel(Z=-1000, method='nearest').mean('time').plot()

# %%
Vp =  ds_model.V -  ds_model.V.mean('time')
Cp =  ds_model.PTRACER01 -  ds_model.PTRACER01.mean('time')

# %%
grid = Grid(ds_model, periodic='X')

# %%
VpCp = grid.interp(Vp, 'Y', boundary='extend') * Cp

# %%
VpCp.sel(Z=-1000, XC=0, YC=1000e3, method='nearest').mean('time').values
# Out:
# array(-0.00119943, dtype=float32)

# %%
plt.figure(figsize=(15,3))

plt.subplot(131)
bins = np.linspace(-0.4, 0.4,27)
Vp.sel(Z=-1000, XC=0, YG=1000e3, method='nearest').plot.hist(bins=bins);
plt.yscale('log')

plt.subplot(132)
bins = np.linspace(-0.25, 0.25, 27)
Cp.sel(Z=-1000, XC=0, YC=1000e3, method='nearest').plot.hist(bins=bins);
plt.yscale('log')

plt.subplot(133)
bins = np.linspace(-0.05, 0.05,27)
VpCp.sel(Z=-1000, XC=0, YC=1000e3, method='nearest').plot.hist(bins=bins);
plt.yscale('log')

# %%
import scipy.stats as sp

# %%
print((Vp.sel(Z=-1000, XC=0, YG=1000e3, method='nearest')).mean('time').values, 
      np.median(Vp.sel(Z=-1000, XC=0, YG=1000e3, method='nearest')),  )
# Out:
# -3.371576e-09 -0.003225842

# %%
sp.skew(Vp.sel(Z=-1000, XC=0, YG=1000e3, method='nearest'))
# Out:
# 0.08585632592439651

# %%
sp.kurtosis(Vp.sel(Z=-1000, XC=0, YG=1000e3, method='nearest'))
# Out:
# -0.3671563709815553

# %%
bins = np.linspace(-0.05, 0.05,27)
VpCp.sel(Z=-100, XC=1200e3, YC=1000e3, method='nearest').plot.hist(bins=bins);
plt.yscale('log')

# %%
ds_model.PTRACER01.sel(XC=1200e3, YC=1000e3, method='nearest').isel(time=-1).plot(Marker='.')
ds_model.PTRACER03.sel(XC=1200e3, YC=1000e3, method='nearest').isel(time=-1).plot(Marker='.')
ds_model.PTRACER05.sel(XC=1200e3, YC=1000e3, method='nearest').isel(time=-1).plot(Marker='.')
ds_model.PTRACER07.sel(XC=1200e3, YC=1000e3, method='nearest').isel(time=-1).plot(Marker='.')
ds_model.PTRACER09.sel(XC=1200e3, YC=1000e3, method='nearest').isel(time=-1).plot(Marker='.')
ds_model.PTRACER11.sel(XC=1200e3, YC=1000e3, method='nearest').isel(time=-1).plot(Marker='.')
ds_model.PTRACER13.sel(XC=1200e3, YC=1000e3, method='nearest').isel(time=-1).plot(Marker='.')

# %%
ds_model
# Out:
# <xarray.Dataset>
# Dimensions:              (XC: 400, XG: 400, YC: 400, YG: 400, Z: 40, Zl: 40, Zp1: 41, Zu: 40, layer_1TH_bounds: 43, layer_1TH_center: 42, layer_1TH_interface: 41, time: 1980)
# Coordinates:
#     Depth                (YC, XC) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#     PHrefC               (Z) float32 dask.array<shape=(40,), chunksize=(1,)>
#     PHrefF               (Zp1) float32 dask.array<shape=(41,), chunksize=(41,)>
#   * XC                   (XC) float32 2500.0 7500.0 ... 1992500.0 1997500.0
#   * XG                   (XG) float32 0.0 5000.0 10000.0 ... 1990000.0 1995000.0
#   * YC                   (YC) float32 2500.0 7500.0 ... 1992500.0 1997500.0
#   * YG                   (YG) float32 0.0 5000.0 10000.0 ... 1990000.0 1995000.0
#   * Z                    (Z) float32 -5.0 -15.0 -25.0 ... -2830.5 -2933.5
#   * Zl                   (Zl) float32 0.0 -10.0 -20.0 ... -2779.0 -2882.0
#   * Zp1                  (Zp1) float32 0.0 -10.0 -20.0 ... -2882.0 -2985.0
#   * Zu                   (Zu) float32 -10.0 -20.0 -30.0 ... -2882.0 -2985.0
#     drC                  (Zp1) float32 dask.array<shape=(41,), chunksize=(41,)>
#     drF                  (Z) float32 dask.array<shape=(40,), chunksize=(1,)>
#     dxC                  (YC, XG) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#     dxG                  (YG, XC) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#     dyC                  (YG, XC) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#     dyG                  (YC, XG) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#     hFacC                (Z, YC, XC) float32 dask.array<shape=(40, 400, 400), chunksize=(1, 400, 400)>
#     hFacS                (Z, YG, XC) float32 dask.array<shape=(40, 400, 400), chunksize=(1, 400, 400)>
#     hFacW                (Z, YC, XG) float32 dask.array<shape=(40, 400, 400), chunksize=(1, 400, 400)>
#     iter                 (time) int64 dask.array<shape=(1980,), chunksize=(35,)>
#   * layer_1TH_bounds     (layer_1TH_bounds) float32 -0.2 0.0 0.2 ... 7.8 8.0 8.2
#   * layer_1TH_center     (layer_1TH_center) float32 -0.1 0.1 0.3 ... 7.7 7.9 8.1
#   * layer_1TH_interface  (layer_1TH_interface) float32 0.0 0.2 0.4 ... 7.8 8.0
#     maskC                (Z, YC, XC) bool dask.array<shape=(40, 400, 400), chunksize=(1, 400, 400)>
#     maskS                (Z, YG, XC) bool dask.array<shape=(40, 400, 400), chunksize=(1, 400, 400)>
#     maskW                (Z, YC, XG) bool dask.array<shape=(40, 400, 400), chunksize=(1, 400, 400)>
#     rA                   (YC, XC) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#     rAs                  (YG, XC) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#     rAw                  (YC, XG) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#     rAz                  (YG, XG) float32 dask.array<shape=(400, 400), chunksize=(400, 400)>
#   * time                 (time) timedelta64[ns] 61023 days ... 66960 days
# Data variables:
#     Eta                  (time, YC, XC) float32 dask.array<shape=(1980, 400, 400), chunksize=(35, 400, 400)>
#     PH                   (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PHL                  (time, YC, XC) float32 dask.array<shape=(1980, 400, 400), chunksize=(35, 400, 400)>
#     PTRACER01            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER02            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER03            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER04            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER05            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER06            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER07            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER08            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER09            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER10            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER11            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER12            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER13            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER14            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER15            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER16            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER17            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER18            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER19            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     PTRACER20            (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     T                    (time, Z, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     U                    (time, Z, YC, XG) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     V                    (time, Z, YG, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
#     W                    (time, Zl, YC, XC) float32 dask.array<shape=(1980, 40, 400, 400), chunksize=(35, 1, 400, 400)>
